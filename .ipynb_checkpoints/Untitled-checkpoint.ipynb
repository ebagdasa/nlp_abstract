# %%
import matplotlib.pyplot as plt; plt.rcdefaults()
import numpy as np

from matplotlib import ticker

from matplotlib.patches import Ellipse, Polygon

fig = plt.figure(facecolor="white", figsize=(5, 4.5))
ax1 = fig.add_subplot(111)
objects = ['G','U','X-PV', 'X-HV']
y_pos = np.arange(len(objects))
performance = [14156.776,
36188.276,
31574.262, 
36866.854]
errorbars= [453.63525,
49.86913,
165.20062,
358.66973]

ax = plt.gca()
mkfunc = lambda x, pos: '%1.1fM' % (x * 1e-6) if x >= 1e6 else '%1.0fK' % (x * 1e-3) if x >= 1e3 else '%1.1f' % x
mkformatter = ticker.FuncFormatter(mkfunc)
ax.yaxis.set_major_formatter(mkformatter)

pat = ['--','//','\\\\','xx']
pac = ['g', 'k','b','b']

# [ ‘/’ | ‘\’ | ‘|’ | ‘-‘ | ‘+’ | ‘x’ | ‘o’ | ‘O’ | ‘.’ | ‘*’ ]

for pos, x in  enumerate(list(zip(objects,performance))):

    ax1.bar([pos], [x[1]],align='center' ,color='none', edgecolor=pac[pos], hatch=pat[pos], lw=0., zorder = 0)
    ax1.bar([pos], [x[1]], align='center', color='none', edgecolor='k', 
            yerr=[errorbars[pos]], ecolor='k', error_kw={'capthick':2}, lw=2.5, capsize=10)
plt.xticks(y_pos,objects, fontsize = 18)
ax1.set_ylabel('Throughput(Requests/S)' , fontsize=26)
ax1.tick_params(axis='both', which='major', labelsize=24)

plt.savefig('fig1.eps', format='eps', transparent=True, bbox_inches='tight', pad_inches=0.1)
plt.show()
# Out:
# /home/ubuntu/myvenv/lib/python3.5/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')
# /home/ubuntu/myvenv/lib/python3.5/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %%
import matplotlib.pyplot as plt; plt.rcdefaults()
import numpy as np

from matplotlib import ticker

from matplotlib.patches import Ellipse, Polygon

fig = plt.figure(facecolor="white", figsize=(5, 4.5))
ax1 = fig.add_subplot(111)
objects = ['U','X-PV', 'X-HV']
y_pos = np.arange(len(objects))
performance = [1458.616,
7533.222,
8014.26]
errorbars= [6.50578,
61.03685,
4.42919]

ax = plt.gca()
mkfunc = lambda x, pos: '%1.1fM' % (x * 1e-6) if x >= 1e6 else '%1.0fK' % (x * 1e-3) if x >= 1e3 else '%1.1f' % x
mkformatter = ticker.FuncFormatter(mkfunc)
ax.yaxis.set_major_formatter(mkformatter)

pat = ['//','\\\\','xx']
pac = ['k','b','b']


for pos, x in  enumerate(list(zip(objects,performance))):

    ax1.bar([pos], [x[1]],align='center' ,color='none', edgecolor='k', hatch=pat[pos], lw=1., zorder = 0)
    ax1.bar([pos], [x[1]], align='center', color=pac[pos], edgecolor='k', 
            yerr=[errorbars[pos]], ecolor='k', error_kw={'capthick':2}, lw=1.5, capsize=10, hatch=pat[pos], lw=1., zorder = 0)
plt.xticks(y_pos,objects, fontsize = 18)
ax1.set_ylabel('Throughput(Requests/S)' , fontsize=26)
ax1.tick_params(axis='both', which='major', labelsize=24)




ax1.set_ylim([0,10000])
plt.savefig('fig2.eps', format='eps', transparent=True, bbox_inches='tight', pad_inches=0.1)
plt.show()

# %%
import matplotlib.pyplot as plt; plt.rcdefaults()
import numpy as np

from matplotlib import ticker

from matplotlib.patches import Ellipse, Polygon

fig = plt.figure(facecolor="white", figsize=(5, 4.5))
ax1 = fig.add_subplot(111)
objects = ['G','X-PV', 'X-HV']
y_pos = np.arange(len(objects))
performance = [55798.104,
84928.95,
87025.606]
errorbars= [479.05029,
4003.33731,
2184.44074]

ax = plt.gca()
mkfunc = lambda x, pos: '%1.1fM' % (x * 1e-6) if x >= 1e6 else '%1.0fK' % (x * 1e-3) if x >= 1e3 else '%1.1f' % x
mkformatter = ticker.FuncFormatter(mkfunc)
ax.yaxis.set_major_formatter(mkformatter)

pat = ['--','\\\\','xx']
pac = ['g','b','b']




for pos, x in  enumerate(list(zip(objects,performance))):

    ax1.bar([pos], [x[1]],align='center' ,color='none', edgecolor=pac[pos], hatch=pat[pos], lw=1.,  zorder = 0)
    ax1.bar([pos], [x[1]], align='center', color='none', edgecolor='k', 
            yerr=[errorbars[pos]], ecolor='k', error_kw={'capthick':2}, lw=1.5, linewidth=10., capsize=10)
plt.xticks(y_pos,objects, fontsize = 18)
ax1.set_ylabel('Throughput(Requests/S)' , fontsize=26)
ax1.tick_params(axis='both', which='major', labelsize=24)




ax1.set_ylim([0,100000])
 
plt.savefig('fig3.eps', format='eps', transparent=True, bbox_inches='tight', pad_inches=0.1)
plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib.patches import Ellipse, Polygon

fig = plt.figure()
ax1 = fig.add_subplot(131)
ax1.bar(range(1, 5), range(1, 5), color='green', edgecolor='black', hatch="/")
ax1.bar(range(1, 5), [6] * 4, bottom=range(1, 5), color='blue', edgecolor='black', hatch='//')
ax1.set_xticks([1.5, 2.5, 3.5, 4.5])

# ax2 = fig.add_subplot(132)
# bars = ax2.bar(range(1, 5), range(1, 5), color='yellow', ecolor='black') + \
#     ax2.bar(range(1, 5), [6] * 4, bottom=range(1, 5), color='green', ecolor='black')
# ax2.set_xticks([1.5, 2.5, 3.5, 4.5])

# patterns = ('-', '+', 'x', '\\', '*', 'o', 'O', '.')
# for bar, pattern in zip(bars, patterns):
#     bar.set_hatch(pattern)

# ax3 = fig.add_subplot(133)
# ax3.fill([1, 3, 3, 1], [1, 1, 2, 2], fill=False, hatch='\\')
# ax3.add_patch(Ellipse((4, 1.5), 4, 0.5, fill=False, hatch='*'))
# ax3.add_patch(Polygon([[0, 0], [4, 1.1], [6, 2.5], [2, 1.4]], closed=True,
#                       fill=False, hatch='/'))
# ax3.set_xlim((0, 6))
# ax3.set_ylim((0, 2.5))

plt.show()
